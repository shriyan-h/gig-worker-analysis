# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('gig_worker_income_dirty.csv')
# Out:
# /tmp/ipykernel_2966/984237416.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('gig_worker_income_dirty.csv')

# %%
df.head()
# Out:
#    worker_id        date    city platform vehicle_type worker_type   age  \
# 0          1  01-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 1          1  02-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 2          1  03-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 3          1  04-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 4          1  05-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
#
#    experience_years weekend weather  ...  gross_income  fuel_price  fuel_cost  \
# 0               0.7   False   Rainy  ...        810.98      103.40      86.23
# 1               0.7   False   Sunny  ...       1603.64      103.50     185.77
# 2               0.7   False   Sunny  ...       1747.05      103.26     147.98
# 3               0.7    True  Cloudy  ...       2307.97      102.68     206.78
# 4               0.7    True  Cloudy  ...       2251.39      103.33     244.77
#
#    maintenance_cost  platform_commission    tips  bonus  customer_rating  \
# 0             36.98               177.41   61.48    0.0              4.3
# 1             47.01               357.15   61.90    0.0              4.1
# 2             65.42               420.09  127.52  100.0              4.4
# 3             61.93               557.14  155.48  200.0              4.2
# 4             65.52               393.21   48.93  150.0              3.8
#
#    cancellation_rate  net_income
# 0               6.97      571.84
# 1               5.56     1075.61
# 2               1.66     1341.08
# 3               5.29     1837.60
# 4               6.65     1746.82
#
# [5 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# worker_id                 0
# date                      0
# city                      0
# platform                  1
# vehicle_type              1
# worker_type               1
# age                       1
# experience_years          1
# weekend                   1
# weather                   1
# festival                  1
# hours_worked              1
# orders_completed          1
# distance_km               1
# gross_income              1
# fuel_price                1
# fuel_cost                 1
# maintenance_cost          1
# platform_commission       1
# tips                   2259
# bonus                   852
# customer_rating        1397
# cancellation_rate         1
# net_income                1
# dtype: int64

# %%
df.shape
# Out:
# (45467, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45467 entries, 0 to 45466
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   worker_id            45467 non-null  int64
#  1   date                 45467 non-null  object
#  2   city                 45467 non-null  object
#  3   platform             45466 non-null  object
#  4   vehicle_type         45466 non-null  object
#  5   worker_type          45466 non-null  object
#  6   age                  45466 non-null  float64
#  7   experience_years     45466 non-null  float64
#  8   weekend              45466 non-null  object
#  9   weather              45466 non-null  object
#  10  festival             45466 non-null  float64
#  11  hours_worked         45466 non-null  float64
#  12  orders_completed     45466 non-null  float64
#  13  distance_km          45466 non-null  float64
#  14  gross_income         45466 non-null  float64
#  15  fuel_price           45466 non-null  float64
#  16  fuel_cost            45466 non-null  float64
#  17  maintenance_cost     45466 non-null  float64
#  18  platform_commission  45466 non-null  float64
#  19  tips                 43208 non-null  float64
#  20  bonus                44615 non-null  float64
#  21  customer_rating      44070 non-null  float64
#  22  cancellation_rate    45466 non-null  float64
#  23  net_income           45466 non-null  float64
# dtypes: float64(16), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# 45466    False
# Length: 45467, dtype: bool

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45467 entries, 0 to 45466
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   worker_id            45467 non-null  int64
#  1   date                 45467 non-null  object
#  2   city                 45467 non-null  object
#  3   platform             45466 non-null  object
#  4   vehicle_type         45466 non-null  object
#  5   worker_type          45466 non-null  object
#  6   age                  45466 non-null  float64
#  7   experience_years     45466 non-null  float64
#  8   weekend              45466 non-null  object
#  9   weather              45466 non-null  object
#  10  festival             45466 non-null  float64
#  11  hours_worked         45466 non-null  float64
#  12  orders_completed     45466 non-null  float64
#  13  distance_km          45466 non-null  float64
#  14  gross_income         45466 non-null  float64
#  15  fuel_price           45466 non-null  float64
#  16  fuel_cost            45466 non-null  float64
#  17  maintenance_cost     45466 non-null  float64
#  18  platform_commission  45466 non-null  float64
#  19  tips                 43208 non-null  float64
#  20  bonus                44615 non-null  float64
#  21  customer_rating      44070 non-null  float64
#  22  cancellation_rate    45466 non-null  float64
#  23  net_income           45466 non-null  float64
# dtypes: float64(16), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
df['tips'] = df['tips'].fillna(0)

# %%
df['bonus'] = df['bonus'].fillna(0)

# %%
df['customer_rating'] = df['customer_rating'].fillna(df['customer_rating'].mean())

# %%
df.head()
# Out:
#    worker_id        date    city platform vehicle_type worker_type   age  \
# 0          1  01-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 1          1  02-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 2          1  03-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 3          1  04-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 4          1  05-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
#
#    experience_years weekend weather  ...  gross_income  fuel_price  fuel_cost  \
# 0               0.7   False   Rainy  ...        810.98      103.40      86.23
# 1               0.7   False   Sunny  ...       1603.64      103.50     185.77
# 2               0.7   False   Sunny  ...       1747.05      103.26     147.98
# 3               0.7    True  Cloudy  ...       2307.97      102.68     206.78
# 4               0.7    True  Cloudy  ...       2251.39      103.33     244.77
#
#    maintenance_cost  platform_commission    tips  bonus  customer_rating  \
# 0             36.98               177.41   61.48    0.0              4.3
# 1             47.01               357.15   61.90    0.0              4.1
# 2             65.42               420.09  127.52  100.0              4.4
# 3             61.93               557.14  155.48  200.0              4.2
# 4             65.52               393.21   48.93  150.0              3.8
#
#    cancellation_rate  net_income
# 0               6.97      571.84
# 1               5.56     1075.61
# 2               1.66     1341.08
# 3               5.29     1837.60
# 4               6.65     1746.82
#
# [5 rows x 24 columns]

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45467 entries, 0 to 45466
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   worker_id            45467 non-null  int64
#  1   date                 45467 non-null  object
#  2   city                 45467 non-null  object
#  3   platform             45466 non-null  object
#  4   vehicle_type         45466 non-null  object
#  5   worker_type          45466 non-null  object
#  6   age                  45466 non-null  float64
#  7   experience_years     45466 non-null  float64
#  8   weekend              45466 non-null  object
#  9   weather              45466 non-null  object
#  10  festival             45466 non-null  float64
#  11  hours_worked         45466 non-null  float64
#  12  orders_completed     45466 non-null  float64
#  13  distance_km          45466 non-null  float64
#  14  gross_income         45466 non-null  float64
#  15  fuel_price           45466 non-null  float64
#  16  fuel_cost            45466 non-null  float64
#  17  maintenance_cost     45466 non-null  float64
#  18  platform_commission  45466 non-null  float64
#  19  tips                 45467 non-null  float64
#  20  bonus                45467 non-null  float64
#  21  customer_rating      45467 non-null  float64
#  22  cancellation_rate    45466 non-null  float64
#  23  net_income           45466 non-null  float64
# dtypes: float64(16), int64(1), object(7)
# memory usage: 8.3+ MB

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45462    False
# 45463    False
# 45464    False
# 45465    False
# 45466    False
# Length: 45467, dtype: bool

# %%
df.head()
# Out:
#    worker_id        date    city platform vehicle_type worker_type   age  \
# 0          1  01-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 1          1  02-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 2          1  03-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 3          1  04-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
# 4          1  05-01-2025  Jaipur   Swiggy         Bike   Part-Time  28.0
#
#    experience_years weekend weather  ...  gross_income  fuel_price  fuel_cost  \
# 0               0.7   False   Rainy  ...        810.98      103.40      86.23
# 1               0.7   False   Sunny  ...       1603.64      103.50     185.77
# 2               0.7   False   Sunny  ...       1747.05      103.26     147.98
# 3               0.7    True  Cloudy  ...       2307.97      102.68     206.78
# 4               0.7    True  Cloudy  ...       2251.39      103.33     244.77
#
#    maintenance_cost  platform_commission    tips  bonus  customer_rating  \
# 0             36.98               177.41   61.48    0.0              4.3
# 1             47.01               357.15   61.90    0.0              4.1
# 2             65.42               420.09  127.52  100.0              4.4
# 3             61.93               557.14  155.48  200.0              4.2
# 4             65.52               393.21   48.93  150.0              3.8
#
#    cancellation_rate  net_income
# 0               6.97      571.84
# 1               5.56     1075.61
# 2               1.66     1341.08
# 3               5.29     1837.60
# 4               6.65     1746.82
#
# [5 rows x 24 columns]

# %%
df = df.drop('worker_id',axis = True)

# %%
df = df.drop('date',axis = True)

# %%
df
# Out:
#           city platform vehicle_type worker_type   age  experience_years  \
# 0       Jaipur   Swiggy         Bike   Part-Time  28.0               0.7
# 1       Jaipur   Swiggy         Bike   Part-Time  28.0               0.7
# 2       Jaipur   Swiggy         Bike   Part-Time  28.0               0.7
# 3       Jaipur   Swiggy         Bike   Part-Time  28.0               0.7
# 4       Jaipur   Swiggy         Bike   Part-Time  28.0               0.7
# ...        ...      ...          ...         ...   ...               ...
# 45462  Chennai   Swiggy         Bike   Full-Time  55.0               7.7
# 45463  Chennai   Swiggy         Bike   Full-Time  55.0               7.7
# 45464  Chennai   Swiggy         Bike   Full-Time  55.0               7.7
# 45465  Chennai   Swiggy         Bike   Full-Time  55.0               7.7
# 45466    Chenn      NaN          NaN         NaN   NaN               NaN
#
#       weekend weather  festival  hours_worked  ...  gross_income  fuel_price  \
# 0       False   Rainy       0.0           4.1  ...        810.98      103.40
# 1       False   Sunny       0.0           5.1  ...       1603.64      103.50
# 2       False   Sunny       0.0           6.1  ...       1747.05      103.26
# 3        True  Cloudy       0.0           8.4  ...       2307.97      102.68
# 4        True  Cloudy       0.0           8.0  ...       2251.39      103.33
# ...       ...     ...       ...           ...  ...           ...         ...
# 45462   False   Sunny       0.0          11.1  ...       2717.09      102.21
# 45463   False   Rainy       0.0           7.8  ...       1731.80      107.47
# 45464   False  Cloudy       0.0           9.2  ...       2340.86      104.03
# 45465   False   Sunny       0.0          10.9  ...       2564.92      101.71
# 45466     NaN     NaN       NaN           NaN  ...           NaN         NaN
#
#        fuel_cost  maintenance_cost  platform_commission    tips  bonus  \
# 0          86.23             36.98               177.41   61.48    0.0
# 1         185.77             47.01               357.15   61.90    0.0
# 2         147.98             65.42               420.09  127.52  100.0
# 3         206.78             61.93               557.14  155.48  200.0
# 4         244.77             65.52               393.21   48.93  150.0
# ...          ...               ...                  ...     ...    ...
# 45462     318.74             41.08               658.76  159.70   50.0
# 45463     173.92             61.96               314.92   61.65    0.0
# 45464     211.63             43.31               390.49  175.17    0.0
# 45465     295.93             54.98               449.02  143.45    0.0
# 45466        NaN               NaN                  NaN    0.00    0.0
#
#        customer_rating  cancellation_rate  net_income
# 0             4.300000               6.97      571.84
# 1             4.100000               5.56     1075.61
# 2             4.400000               1.66     1341.08
# 3             4.200000               5.29     1837.60
# 4             3.800000               6.65     1746.82
# ...                ...                ...         ...
# 45462         4.000000               2.43     1908.21
# 45463         4.500000               9.78     1242.65
# 45464         4.600000               6.42     1870.60
# 45465         4.400000               7.65     1908.44
# 45466         4.271003                NaN         NaN
#
# [45467 rows x 22 columns]
